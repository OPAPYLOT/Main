# %%
! pip install streamlit -q

# %% [markdown]
# Code de l'app "OPA 2022.py"

# %%
# %%writefile OPA2022.py
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import streamlit as st
from PIL import Image
from google.colab import files



page = st.selectbox("Choose your page", ["Présentation", "Visualisation", "Modélisation"])
if page == "Présentation":
  st.write("""
## OPA Pylot
""")

  st.write("""
Le but de l'outil OPA Pylot est de permettre à l'utilisateur de prédire la performance voire le cours à terme d'une equity du CAC40

La prédiction est à intervalle court terme
""")

  st.write("""
## Historique actions du CAC40
""")
  st.write("""
Nous allons explorer trois secteurs du cac 40 : industrie , luxe et finance

Exploration des Data:

l'API YahooFinance est la source principale de nos données. Pour cela nous importons les deux packages pandas_datareader et yfinance a l'aide de la commande :

● pip install pandas_datareader

● pip install yfinance

L'idée est de se baser sur ces packages pour extraire les données financières associées au CAC40

""")
  image = Image.open('/content/drive/MyDrive/image streamlit/1.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/2.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/3.png')
  st.image(image)

  st.write("""
## Closing Price
""")
  st.write("""
Nous avons ensuite analysé les actions individuelles des entreprises sélectionnées. Nous avons tracé l'historique des cours de clôture et le volume échangé pour chaque action. Cela nous a permis de visualiser l'évolution des prix des actions et de comprendre l'impact du volume sur les variations des prix.
Afin de différencier les tendances par action, on va afficher l'historique des cours de clôture par action
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/4.png')
  st.image(image)

elif page == "Visualisation":
  st.write("""
## Volume Price
""")
  st.write("""
Le cours de l'action nous donne une idée de l'évolution de l'action unitaire au niveau du marché, le prix d'action dépend aussi du volume tradé courant la période.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/5.png')
  st.image(image)

  st.write("""
## Moving Average
""")
  st.write("""
Nous avons calculé la moyenne mobile du cours de l'action pour différentes fenêtres temporelles (10, 20 et 50 jours). Cela nous a permis de lisser les variations à court terme et d'identifier les tendances à plus long terme
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/6.png')
  st.image(image)
  st.write("""
## RENDEMENT QUOTIDIENT
""")
  st.write("""
Nous avons calculé le rendement quotidien de chaque action en utilisant la fonction pct_change() du package pandas. En traçant l'historique des rendements quotidiens, nous avons pu observer les variations et les performances des actions.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/7.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/8.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/9.png')
  st.image(image)

  st.write("""
## Corrélation entre les actions
""")
  st.write("""
Nous pouvons donc maintenant voir que si deux actions sont parfaitement (et positivement) corrélées entre elles, une relation linéaire entre leurs valeurs de rendement quotidiennes devrait se produire.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/10.png')
  st.image(image)
  st.write("""
Cette analyse nous a permis de visualiser les relations linéaires entre les rendements quotidiens des différentes actions
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/11.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/12.png')
  st.image(image)
  st.write("""
## Analyse des risques
""")
  st.write("""
Enfin, nous avons quantifié le risque de notre portefeuille d'actions en comparant le rendement attendu à l'écart type des rendements quotidiens. En traçant le rendement attendu en fonction du risque, nous avons pu identifier les actions présentant un rapport risque/rendement optimal.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/13.png')
  st.image(image)
elif page == "Modélisation":
  st.write("""
## Modélisation des données :
CAPM ( MEDAF : Modèle d’évaluation des actifs financiers)
""")
  st.write("""
Nous avons collecté les données du CAC40 sur une période d'un an, de 2022 à 2023, en utilisant le package yfinance. En calculant les rendements quotidiens des actions du CAC40 et de l'indice lui-même, nous avons pu analyser les variations et les relations entre les rendements. Aussi,nous avons tracé des graphiques de dispersion pour chaque actif par rapport à l'indice CAC40 afin d'observer la corrélation entre les rendements. Cela nous a permis de visualiser la relation linéaire entre les rendements des actifs individuels et l'indice.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/14.png')
  st.image(image)
  st.write("""
Afin de poursuivre notre analyse nous avons tracé à nouveau les graphiques de dispersion, cette fois en incluant la droite de régression linéaire correspondant au modèle CAPM. Cela nous a permis de visualiser la relation entre les rendements des actifs et l'indice de référence, ainsi que d'évaluer l'ajustement des données au modèle CAPM.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/15.png')
  st.image(image)
  st.write("""
En utilisant les paramètres du modèle CAPM (bêta, rendement du marché et taux sans risque), nous avons calculé la rentabilité espérée de chaque actif. La rentabilité espérée représente le rendement attendu de l'actif en fonction de son risque systématique.

18.859 est la rentabilité espérée de l'asset :  CS.PA

23.184 est la rentabilité espérée de l'asset :  GLE.PA

22.145 est la rentabilité espérée de l'asset :  BNP.PA

19.267 est la rentabilité espérée de l'asset :  ACA.PA
""")

  st.write("""
## Modélisation des données :
Mouvement Brownien Géométrique
""")
  st.write("""
Dans l'ensemble, ce code est une illustration basique d'une technique de modélisation des prix des actifs en finance qui utilise le concept de mouvement brownien géométrique, très populaire dans le cadre du modèle de Black-Scholes pour les options de prix.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/16.png')
  st.image(image)

  st.write("""
## Modélisation des données :
LSTM
""")
  st.write("""
Cette partie se concentre sur l'application du modèle LSTM (Long Short-Term Memory) pour la prédiction des prix de clôture des actions financières. Pour cela, nous avons utilisé l'exemple de l’action AXA, afin de mesurer et prédire le cours à court terme.
Nous avons commencé par explorer les données en traçant les prix de clôture de l’action au fil du temps. Cela nous a permis d'observer les tendances et les variations des prix.
Nous avons préparé les données en sélectionnant une action spécifique (AXA) et en filtrant uniquement la colonne des prix de clôture. Ensuite, nous avons converti les dates au format datetime et tracé le graphique des prix de clôture.
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/17.png')
  st.image(image)

  st.write("""
 Enfin, la fonction ajoute également une colonne 'Target' correspondant aux valeurs d'origine de la colonne 'Close'. Le DataFrame résultant est renvoyé après avoir supprimé les lignes contenant des valeurs manquantes (dropna).
""")
  image = Image.open('/content/drive/MyDrive/image streamlit/18.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/19.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/20.png')
  st.image(image)
  st.write("""
En résumé, cette partie définit, compile et entraîne un modèle de réseau de neurones récurrents (LSTM) à l'aide de TensorFlow. Le modèle est configuré avec des couches LSTM et denses, et il est entraîné avec des données d'entrée X_train et des valeurs cibles y_train. L'optimiseur Adam est utilisé pour minimiser la fonction de perte (MSE) et les métriques d'erreur absolue moyenne sont calculées pendant l'entraînement.
""")


  st.write("""
Prédictions sur l'ensemble d'entraînement :
""")

  image = Image.open('/content/drive/MyDrive/image streamlit/21.png')
  st.image(image)
  st.write("""
Prédictions sur l'ensemble de validation :
""")
  st.write("""MAE:0.2243 et MSE: 0.2011""")

  image = Image.open('/content/drive/MyDrive/image streamlit/22.png')
  st.image(image)
  st.write("""
Prédictions sur l'ensemble de test :
""")

  image = Image.open('/content/drive/MyDrive/image streamlit/23.png')
  st.image(image)
  image = Image.open('/content/drive/MyDrive/image streamlit/24.png')
  st.image(image)
# Out:
# Overwriting OPA2022.py

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.384s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# !streamlit run OPA2022.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.194.69.94
# npx: installed 22 in 1.927s
# your url is: https://easy-berries-spend.loca.lt
